# %%
# %matplotlib notebook
import pandas as pd
import seaborn as sns
import warnings
import matplotlib as plot
import matplotlib.pyplot as plt
from eda_3 import *

warnings.simplefilter('ignore')
pd.options.display.max_columns = 300
sns.set_style('darkgrid')

# %%
raw_data = get_raw_data() #need to change this to a sql query so it will work from anywhere

# %%
raw_data['psc_description'] = raw_data['product_or_service_code_description'].copy() #renaming so it doesn't get deleted for having 'code' in header

# %%
def initial_scrub(input_df):
    '''description'''
    raw_data_df = input_df.copy()
    list_of_code_headers = list(raw_data_df.filter(regex='code'))
    no_code_df = raw_data_df[raw_data_df.columns.drop(list_of_code_headers)]
    list_of_recipient_headers = list(no_code_df.filter(regex='recipient'))
    no_recipient_df = no_code_df[no_code_df.columns.drop(list_of_recipient_headers)]
    list_of_business_headers = list(no_recipient_df.filter(regex='business'))
    no_business_df = no_recipient_df[no_recipient_df.columns.drop(list_of_business_headers)]
    #need to drop other columns assciated with award winner, since these aren't known when award is announced
    return no_business_df, list_of_code_headers, list_of_recipient_headers, list_of_business_headers

# %%
def data_summary(input_df):
    '''this function produces a summary of a raw data set. the summary contains three facts about each column of the
    raw dataset: 1. the non-null count 2. the unique values contained in the column 3. the data type contained in the
    column; this data type is determined by pandas, I think, and might not be exactly correct all of the time'''
    working_df = input_df.copy()
    column_null_counts = working_df.isnull().sum()
    column_non_null_counts = len(working_df)-column_null_counts
    unique_entries_per_column = working_df.nunique()
    data_type = working_df.dtypes
    summary_df = pd.concat([column_non_null_counts,unique_entries_per_column,data_type],axis=1)
    summary_df.columns =  ['non_null_counts','unique_value_counts','data_type']
    return summary_df

# %%
smaller_raw_df, dropped_code_headers, dropped_recipient_headers, dropped_business_headers = initial_scrub(raw_data)

# %%
len(dropped_code_headers)
# Out:
# 63

# %%
len(dropped_recipient_headers)
# Out:
# 13

# %%
len(dropped_business_headers)
# Out:
# 22

# %% [markdown]
# Include verification that headers containing "code" are redundant

# %%
smaller_raw_summary = data_summary(smaller_raw_df)

# %%
smaller_raw_summary.head()
# Out:
#                                  non_null_counts  unique_value_counts  \
# contract_transaction_unique_key          1000000              1000000
# award_id_piid                            1000000               376482
# modification_number                      1000000                 2330
# transaction_number                       1000000                   19
# parent_award_agency_id                    780144                   30
#
#                                 data_type
# contract_transaction_unique_key    object
# award_id_piid                      object
# modification_number                object
# transaction_number                  int64
# parent_award_agency_id             object

# %%
smaller_raw_summary.data_type.value_counts()
# Out:
# object     154
# float64     22
# int64        3
# Name: data_type, dtype: int64

# %%
object_column_df = smaller_raw_summary[smaller_raw_summary.data_type=='object']
float64_column_df = smaller_raw_summary[smaller_raw_summary.data_type=='float64']
int64_column_df = smaller_raw_summary[smaller_raw_summary.data_type=='int64']

# %%
int64_column_df
# Out:
#                          non_null_counts  unique_value_counts data_type
# transaction_number               1000000                   19     int64
# action_date_fiscal_year          1000000                    1     int64
# number_of_actions                1000000                  238     int64

# %%
float64_column_df
# Out:
#                                                     non_null_counts  \
# federal_action_obligation                                   1000000
# total_dollars_obligated                                       90525
# base_and_exercised_options_value                            1000000
# current_total_value_of_award                                 185370
# base_and_all_options_value                                  1000000
# potential_total_value_of_award                               185370
# ordering_period_end_date                                          0
# sam_exception                                                  1005
# primary_place_of_performance_congressional_dist...           952081
# idv_type                                                          0
# multiple_or_single_award_idv                                      0
# number_of_offers_received                                    978093
# price_evaluation_adjustment_preference_percent_...            61302
# program_acronym                                                   0
# number_of_employees                                          999682
# annual_revenue                                               999682
# solicitation_date                                                 0
# highly_compensated_officer_1_amount                             787
# highly_compensated_officer_2_amount                             747
# highly_compensated_officer_3_amount                             725
# highly_compensated_officer_4_amount                             713
# highly_compensated_officer_5_amount                             692
#
#                                                     unique_value_counts  \
# federal_action_obligation                                        413361
# total_dollars_obligated                                           64257
# base_and_exercised_options_value                                 405430
# current_total_value_of_award                                     108519
# base_and_all_options_value                                       400488
# potential_total_value_of_award                                   108561
# ordering_period_end_date                                              0
# sam_exception                                                         5
# primary_place_of_performance_congressional_dist...                   54
# idv_type                                                              0
# multiple_or_single_award_idv                                          0
# number_of_offers_received                                           179
# price_evaluation_adjustment_preference_percent_...                   15
# program_acronym                                                       0
# number_of_employees                                                3232
# annual_revenue                                                    18759
# solicitation_date                                                     0
# highly_compensated_officer_1_amount                                 189
# highly_compensated_officer_2_amount                                 180
# highly_compensated_officer_3_amount                                 174
# highly_compensated_officer_4_amount                                 168
# highly_compensated_officer_5_amount                                 162
#
#                                                    data_type
# federal_action_obligation                            float64
# total_dollars_obligated                              float64
# base_and_exercised_options_value                     float64
# current_total_value_of_award                         float64
# base_and_all_options_value                           float64
# potential_total_value_of_award                       float64
# ordering_period_end_date                             float64
# sam_exception                                        float64
# primary_place_of_performance_congressional_dist...   float64
# idv_type                                             float64
# multiple_or_single_award_idv                         float64
# number_of_offers_received                            float64
# price_evaluation_adjustment_preference_percent_...   float64
# program_acronym                                      float64
# number_of_employees                                  float64
# annual_revenue                                       float64
# solicitation_date                                    float64
# highly_compensated_officer_1_amount                  float64
# highly_compensated_officer_2_amount                  float64
# highly_compensated_officer_3_amount                  float64
# highly_compensated_officer_4_amount                  float64
# highly_compensated_officer_5_amount                  float64

# %% [markdown]
# Many of the columns that contain data type float64 (above table) appear to be monetary

# %%
float64_column_df_null_filtered = float64_column_df[float64_column_df.non_null_counts>0.2*raw_data.shape[0]]

# %%
float64_column_df_null_filtered
# Out:
#                                                     non_null_counts  \
# federal_action_obligation                                   1000000
# base_and_exercised_options_value                            1000000
# base_and_all_options_value                                  1000000
# primary_place_of_performance_congressional_dist...           952081
# number_of_offers_received                                    978093
# number_of_employees                                          999682
# annual_revenue                                               999682
#
#                                                     unique_value_counts  \
# federal_action_obligation                                        413361
# base_and_exercised_options_value                                 405430
# base_and_all_options_value                                       400488
# primary_place_of_performance_congressional_dist...                   54
# number_of_offers_received                                           179
# number_of_employees                                                3232
# annual_revenue                                                    18759
#
#                                                    data_type
# federal_action_obligation                            float64
# base_and_exercised_options_value                     float64
# base_and_all_options_value                           float64
# primary_place_of_performance_congressional_dist...   float64
# number_of_offers_received                            float64
# number_of_employees                                  float64
# annual_revenue                                       float64

# %%
object_column_df
# Out:
#                                                  non_null_counts  \
# contract_transaction_unique_key                          1000000
# award_id_piid                                            1000000
# modification_number                                      1000000
# parent_award_agency_id                                    780144
# parent_award_agency_name                                  175468
# parent_award_id                                           780144
# parent_award_modification_number                          803075
# action_date                                              1000000
# period_of_performance_start_date                         1000000
# period_of_performance_current_end_date                   1000000
# period_of_performance_potential_end_date                 1000000
# awarding_agency_name                                     1000000
# awarding_sub_agency_name                                 1000000
# awarding_office_name                                     1000000
# funding_agency_name                                      1000000
# funding_sub_agency_name                                  1000000
# funding_office_name                                       998593
# treasury_accounts_funding_this_award                        4990
# federal_accounts_funding_this_award                         4990
# foreign_funding                                           196806
# foreign_funding_description                              1000000
# sam_exception_description                                 918202
# primary_place_of_performance_country_name                 999981
# primary_place_of_performance_city_name                    952080
# primary_place_of_performance_county_name                  952119
# primary_place_of_performance_state_name                   952267
# primary_place_of_performance_zip_4                        956128
# award_or_idv_flag                                        1000000
# award_type                                               1000000
# type_of_idc                                               918173
# ...                                                          ...
# transit_authority                                        1000000
# subchapter_scorporation                                  1000000
# limited_liability_corporation                            1000000
# foreign_owned_and_located                                1000000
# for_profit_organization                                  1000000
# nonprofit_organization                                   1000000
# other_not_for_profit_organization                        1000000
# the_ability_one_program                                  1000000
# private_university_or_college                            1000000
# state_controlled_institution_of_higher_learning          1000000
# 1862_land_grant_college                                  1000000
# 1890_land_grant_college                                  1000000
# 1994_land_grant_college                                  1000000
# minority_institution                                     1000000
# historically_black_college                               1000000
# tribal_college                                           1000000
# alaskan_native_servicing_institution                     1000000
# native_hawaiian_servicing_institution                    1000000
# school_of_forestry                                       1000000
# veterinary_college                                       1000000
# dot_certified_disadvantage                               1000000
# c8a_program_participant                                  1000000
# sba_certified_8a_joint_venture                           1000000
# highly_compensated_officer_1_name                            787
# highly_compensated_officer_2_name                            747
# highly_compensated_officer_3_name                            725
# highly_compensated_officer_4_name                            713
# highly_compensated_officer_5_name                            692
# last_modified_date                                       1000000
# psc_description                                          1000000
#
#                                                  unique_value_counts data_type
# contract_transaction_unique_key                              1000000    object
# award_id_piid                                                 376482    object
# modification_number                                             2330    object
# parent_award_agency_id                                            30    object
# parent_award_agency_name                                          25    object
# parent_award_id                                                34678    object
# parent_award_modification_number                                 614    object
# action_date                                                      365    object
# period_of_performance_start_date                                1399    object
# period_of_performance_current_end_date                          5059    object
# period_of_performance_potential_end_date                        5399    object
# awarding_agency_name                                               1    object
# awarding_sub_agency_name                                          24    object
# awarding_office_name                                            1165    object
# funding_agency_name                                               16    object
# funding_sub_agency_name                                           68    object
# funding_office_name                                             8949    object
# treasury_accounts_funding_this_award                             686    object
# federal_accounts_funding_this_award                              223    object
# foreign_funding                                                    3    object
# foreign_funding_description                                        3    object
# sam_exception_description                                         10    object
# primary_place_of_performance_country_name                        168    object
# primary_place_of_performance_city_name                          5203    object
# primary_place_of_performance_county_name                        1414    object
# primary_place_of_performance_state_name                           61    object
# primary_place_of_performance_zip_4                             53490    object
# award_or_idv_flag                                                  1    object
# award_type                                                         8    object
# type_of_idc                                                        1    object
# ...                                                              ...       ...
# transit_authority                                                  2    object
# subchapter_scorporation                                            2    object
# limited_liability_corporation                                      2    object
# foreign_owned_and_located                                          2    object
# for_profit_organization                                            2    object
# nonprofit_organization                                             2    object
# other_not_for_profit_organization                                  2    object
# the_ability_one_program                                            2    object
# private_university_or_college                                      2    object
# state_controlled_institution_of_higher_learning                    2    object
# 1862_land_grant_college                                            2    object
# 1890_land_grant_college                                            2    object
# 1994_land_grant_college                                            2    object
# minority_institution                                               2    object
# historically_black_college                                         2    object
# tribal_college                                                     2    object
# alaskan_native_servicing_institution                               1    object
# native_hawaiian_servicing_institution                              1    object
# school_of_forestry                                                 2    object
# veterinary_college                                                 2    object
# dot_certified_disadvantage                                         2    object
# c8a_program_participant                                            2    object
# sba_certified_8a_joint_venture                                     2    object
# highly_compensated_officer_1_name                                239    object
# highly_compensated_officer_2_name                                227    object
# highly_compensated_officer_3_name                                218    object
# highly_compensated_officer_4_name                                211    object
# highly_compensated_officer_5_name                                204    object
# last_modified_date                                             55959    object
# psc_description                                                 2080    object
#
# [154 rows x 3 columns]

# %%
object_column_df_null_filtered = object_column_df[object_column_df.non_null_counts>0.2*raw_data.shape[0]]

# %%
object_column_df.shape
# Out:
# (154, 3)

# %%
object_column_df_null_filtered.shape
# Out:
# (130, 3)

# %%
def get_filtered_summary_list(summary_df,max_null,min_unique,max_unique):
    null_edited_df = summary_df[summary_df.non_null_counts>=max_null].copy()
    unique_edited_df = null_edited_df[(null_edited_df.unique_value_counts>min_unique)&(null_edited_df.unique_value_counts<max_unique)].copy()
    #data_type_edited_df = unique_edited_df[unique_edited_df.data_type.isin(data_type)].copy()
    #data_type_edited_df = unique_edited_df[unique_edited_df.data_type==data_type].copy()
    column_list = unique_edited_df.index.tolist()
    print('the list is length '+str(len(column_list)))
    return unique_edited_df, column_list

# %%
edited_summary, test_list = get_filtered_summary_list(smaller_raw_summary,800000,3,50)
# Out:
# the list is length 23

# %%
edited_summary
# Out:
#                                                  non_null_counts  \
# transaction_number                                       1000000
# awarding_sub_agency_name                                 1000000
# funding_agency_name                                      1000000
# sam_exception_description                                 918202
# award_type                                               1000000
# type_of_contract_pricing                                 1000000
# contract_bundling                                         999478
# dod_claimant_program_description                          999994
# recovered_materials_sustainability                        998416
# domestic_or_foreign_entity                                916150
# information_technology_commercial_item_category           997802
# epa_designated_product                                    999983
# place_of_manufacture                                      999162
# extent_competed                                           999995
# solicitation_procedures                                   999328
# type_of_set_aside                                         996304
# evaluated_preference                                      997509
# research                                                  918237
# fair_opportunity_limited_sources                          923447
# fed_biz_opps                                              998934
# national_interest_action                                 1000000
# cost_accounting_standards_clause                          919140
# contract_financing                                        999957
#
#                                                  unique_value_counts data_type
# transaction_number                                                19     int64
# awarding_sub_agency_name                                          24    object
# funding_agency_name                                               16    object
# sam_exception_description                                         10    object
# award_type                                                         8    object
# type_of_contract_pricing                                          16    object
# contract_bundling                                                  4    object
# dod_claimant_program_description                                  27    object
# recovered_materials_sustainability                                15    object
# domestic_or_foreign_entity                                         5    object
# information_technology_commercial_item_category                    7    object
# epa_designated_product                                             5    object
# place_of_manufacture                                              16    object
# extent_competed                                                    7    object
# solicitation_procedures                                           10    object
# type_of_set_aside                                                 16    object
# evaluated_preference                                               5    object
# research                                                           7    object
# fair_opportunity_limited_sources                                  12    object
# fed_biz_opps                                                       4    object
# national_interest_action                                          13    object
# cost_accounting_standards_clause                                   4    object
# contract_financing                                                 6    object

# %%
def column_count_cdf(data_df, column):
    column_summary = pd.DataFrame(columns=['count','percent','percent_running_sum'])
    column_summary['count'] = data_df[column].value_counts()
    nonnulls = data_df[column].value_counts().sum()
    column_summary['percent'] = data_df[column].value_counts()/nonnulls*100
    column_summary['percent_running_sum'] = column_summary['percent'].cumsum()
    column_summary = column_summary.reset_index()
    column_summary = column_summary.drop('index',axis=1)
    return column_summary

def plot_cdf(data_df, columnlist):
    max_x = 0
    for column in columnlist:
        print(column)
        colsummary=column_count_cdf(data_df, column)
        colsummary['percent_running_sum'].plot(linewidth=3)
        if max_x<=max(colsummary['count']):
            max_x = max(colsummary['count'])
        print(max_x)
    plt.legend(columnlist, fontsize=12)
    plt.ylim([-5,105])
    plt.xlim(xmin=-5)
    plt.title('Feature Distribution CDF',fontsize=20)
    plt.xlabel('Feature\'s Unique Value',fontsize=15)
    plt.ylabel('% of Non-nul Values',fontsize=15)

# %%
plot_cdf(smaller_raw_df, ['psc_description','naics_description'])
# Out:
# psc_description
# <img src="data:image/png;base64,..." width="800">
# 132578
# naics_description
# 181108

# %%
column_summary = column_count_cdf(smaller_raw_df,'naics_description')

# %%
column_summary
# Out:
#       count    percent  percent_running_sum
# 0    181108  18.153843            18.153843
# 1     70068   7.023453            25.177295
# 2     38592   3.868372            29.045667
# 3     37681   3.777055            32.822723
# 4     36436   3.652260            36.474982
# 5     34515   3.459703            39.934685
# 6     30750   3.082308            43.016993
# 7     24837   2.489603            45.506596
# 8     22141   2.219362            47.725958
# 9     21305   2.135563            49.861522
# 10    20744   2.079330            51.940852
# 11    19150   1.919551            53.860403
# 12    19004   1.904917            55.765320
# 13    18210   1.825328            57.590647
# 14    16658   1.669759            59.260406
# 15    13601   1.363332            60.623739
# 16    11777   1.180499            61.804238
# 17    11749   1.177692            62.981930
# 18    11729   1.175688            64.157618
# 19    10783   1.080863            65.238480
# 20     9916   0.993957            66.232437
# 21     9636   0.965890            67.198327
# 22     7602   0.762007            67.960334
# 23     7133   0.714995            68.675329
# 24     7116   0.713291            69.388620
# 25     6493   0.650843            70.039464
# 26     6029   0.604333            70.643796
# 27     5946   0.596013            71.239810
# 28     5490   0.550305            71.790114
# 29     4796   0.480740            72.270854
# ..      ...        ...                  ...
# 970       1   0.000100            99.997093
# 971       1   0.000100            99.997193
# 972       1   0.000100            99.997294
# 973       1   0.000100            99.997394
# 974       1   0.000100            99.997494
# 975       1   0.000100            99.997594
# 976       1   0.000100            99.997695
# 977       1   0.000100            99.997795
# 978       1   0.000100            99.997895
# 979       1   0.000100            99.997995
# 980       1   0.000100            99.998095
# 981       1   0.000100            99.998196
# 982       1   0.000100            99.998296
# 983       1   0.000100            99.998396
# 984       1   0.000100            99.998496
# 985       1   0.000100            99.998597
# 986       1   0.000100            99.998697
# 987       1   0.000100            99.998797
# 988       1   0.000100            99.998897
# 989       1   0.000100            99.998998
# 990       1   0.000100            99.999098
# 991       1   0.000100            99.999198
# 992       1   0.000100            99.999298
# 993       1   0.000100            99.999399
# 994       1   0.000100            99.999499
# 995       1   0.000100            99.999599
# 996       1   0.000100            99.999699
# 997       1   0.000100            99.999800
# 998       1   0.000100            99.999900
# 999       1   0.000100           100.000000
#
# [1000 rows x 3 columns]

# %%
def get_bucketed_list(column_cdf_df, percent_buckets=20):
    bucketed_list = pd.DataFrame([])
    for bucket in range(1,int(100/percent_bucket_size)+1):
        bucketed_list[i] = column_cdf_df[columns_cdf_df]

# %%
for i in range(1,int(100/20)+1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
from yellowbrick.features import Rank2D

# %%
test_df = smaller_raw_df[['type_of_set_aside','naics_description','psc_description']][0:100000].copy()

# %%
test_df.shape
# Out:
# (100000, 3)

# %%
smaller_test_df = test_df[test_df.naics_description.isin(['COMMERCIAL BAKERIES','ALL OTHER MISCELLANEOUS MANUFACTURING','PETROLEUM REFINERIES'])].copy()

# %%
smaller_test_df.shape
# Out:
# (11325, 3)

# %%
smaller_test_df.isnull().sum()
# Out:
# type_of_set_aside    0
# naics_description    0
# psc_description      0
# dtype: int64

# %%
def get_Xy(input_df, target = 'type_of_set_aside'):
    X = input_df.drop(target,axis=1)
    y = input_df[target]
    return X, y

# %%
models = [
    SVC(gamma='auto'), LinearSVC(),
    SGDClassifier(max_iter=100, tol=1e-3), KNeighborsClassifier(),
    LogisticRegression(solver='lbfgs'), LogisticRegressionCV(cv=3),
    BaggingClassifier(), ExtraTreesClassifier(n_estimators=300),
    RandomForestClassifier(n_estimators=300)
] #NuSVC(gamma='auto') didn't work because of some nu issue?

# %%
def score_model(X, y, estimator, **kwargs):
    """
    Test various estimators.
    """
    y = LabelEncoder().fit_transform(y)
    model = Pipeline([
        ('one_hot_encoder', OneHotEncoder()),
        ('estimator', estimator)
    ])

    # Instantiate the classification model and visualizer
    model.fit(X, y, **kwargs)

    expected  = y
    predicted = model.predict(X)

    # Compute and return F1 (harmonic mean of precision and recall)
    print("{}: {}".format(estimator.__class__.__name__, f1_score(expected, predicted, average='weighted')))

# %%
X, y = get_Xy(smaller_test_df)

# %%
for model in models:
    score_model(X,y,model)
# Out:
# SVC: 0.9784255221094653
# LinearSVC: 0.9793612231584454
# SGDClassifier: 0.9786344588841708
# KNeighborsClassifier: 0.9784255221094653
# LogisticRegression: 0.9784255221094653
# LogisticRegressionCV: 0.9784255221094653
# BaggingClassifier: 0.9790506062056439
# ExtraTreesClassifier: 0.9795675978644472
# RandomForestClassifier: 0.9795675978644472

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
object_column_binary_df = object_column_df[object_column_df.unique_entries_per_column==2].copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-245-e35d7f14f2e9> in <module>
# ----> 1 object_column_binary_df = object_column_df[object_column_df.unique_entries_per_column==2].copy()
#
# c:\users\kalev\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique_entries_per_column'

# %%
object_column_binary_df

# %%
for i in object_column_binary_df.index:
    print(raw_data[i].value_counts())
