# %%
# My (Jack) first attempt at creating a data set to run out machine learning alogrythms.
# Here we narrowed down the data needed from Postgres and then created a .csv
# We originally used that .csv for our models. Later we just incorporated this filtering
# into the same notebook as out models. 


# Import libraries

import psycopg2
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conn = psycopg2.connect(database='usaspending', user='team', password='ZAQ!@#zaq123', host='127.0.0.1', port='5432')

# %%
sql_tbl_name = 'latest'

# %%
sql_cols = ('federal_action_obligation, '
            'total_dollars_obligated, '
            'base_and_exercised_options_value, '
            'base_and_all_options_value, '
            'awarding_sub_agency_name, '
            'awarding_office_name, '
            'funding_sub_agency_name, '
            'funding_office_name, '
            'primary_place_of_performance_state_code, '
            'award_or_idv_flag, '
            'award_type, '
            'type_of_contract_pricing, '
            'dod_claimant_program_description, '
            'type_of_set_aside_code, '
            #'multi_year_contract, '
            #'dod_acquisition_program_description, ' too many NaN
            #'subcontracting_plan, ' too many NaN
            'contract_bundling, '
            #'evaluated_preference, ' too many NaN
            'national_interest_action, '
            #'cost_or_pricing_data, ' too many NaN
            'gfe_gfp, '
            'contract_financing, '
            'portfolio_group, '
            'product_or_service_code_description, '
            'naics_bucket_title, '
            'naics_description'
            )

# %%
df = pd.read_sql_query('SELECT ' + sql_cols + ' FROM ' + sql_tbl_name, con=conn)
df.shape
# Out:
# (250000, 22)

# %%
df = df[pd.notnull(df['type_of_set_aside_code'])]
df.shape
# Out:
# (246740, 22)

# %%
# Create conditional column to determine if set aside is YES or NO

# def set_aside(c):
#     if c['type_of_set_aside_code'] == 'NONE':
#         return 0
#     else:
#         return 1

def contract_value(c):
    if c['base_and_exercised_options_value'] > 0:
        return c['base_and_exercised_options_value']
    elif c['base_and_all_options_value'] > 0:
        return c['base_and_all_options_value']
    elif c['total_dollars_obligated'] > 0:
        return c['total_dollars_obligated']
    elif c['federal_action_obligation'] > 0:
        return c['federal_action_obligation'] 
    else:
        return 0
    
# df['set_aside'] = df.apply(set_aside, axis=1)
df['contract_value'] = df.apply(contract_value, axis=1)

# del df['type_of_set_aside_code']
del df['base_and_exercised_options_value']
del df['base_and_all_options_value']
del df['total_dollars_obligated']
del df['federal_action_obligation']

df2 = df.dropna()
df2.shape
# Out:
# (202234, 19)

# %%
df2.to_csv(r'/home/team/Documents/Data-Oriented-Proposal-Engine/SpendingData/BeforeDummies.csv')

# %%
df3 = df2
df3 = pd.get_dummies(df2)
#filename = r'/home/team/Documents/Data-Oriented-Proposal-Engine/SpendingData/Dummies.csv'
#df3.to_csv(filename)
df3.head()
# Out:
#    set_aside  contract_value  \
# 0          0        64925.82
# 1          0         4897.96
# 3          1         5618.14
# 4          0          163.92
# 7          0       220000.00
#
#    awarding_sub_agency_name_DEFENSE ADVANCED RESEARCH PROJECTS AGENCY  (DARPA)  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    awarding_sub_agency_name_DEFENSE COMMISSARY AGENCY  (DECA)  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    awarding_sub_agency_name_DEFENSE CONTRACT MANAGEMENT AGENCY (DCMA)  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    awarding_sub_agency_name_DEFENSE COUNTERINTELLIGENCE AND SECURITY AGENCY  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    awarding_sub_agency_name_DEFENSE FINANCE AND ACCOUNTING SERVICE (DFAS)  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    awarding_sub_agency_name_DEFENSE HEALTH AGENCY (DHA)  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    awarding_sub_agency_name_DEFENSE HUMAN RESOURCES ACTIVITY  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    awarding_sub_agency_name_DEFENSE INFORMATION SYSTEMS AGENCY (DISA)  ...  \
# 0                                                  0                   ...
# 1                                                  0                   ...
# 3                                                  0                   ...
# 4                                                  1                   ...
# 7                                                  0                   ...
#
#    naics_description_TEXTILE BAG AND CANVAS MILLS  \
# 0                                               0
# 1                                               0
# 3                                               0
# 4                                               0
# 7                                               0
#
#    naics_description_THEATER COMPANIES AND DINNER THEATERS  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    naics_description_THIRD PARTY ADMINISTRATION OF INSURANCE AND PENSION FUNDS  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    naics_description_TOTALIZING FLUID METER AND COUNTING DEVICE MANUFACTURING  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    naics_description_TRANSLATION AND INTERPRETATION SERVICES  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    naics_description_TRAVEL AGENCIES  \
# 0                                  0
# 1                                  0
# 3                                  0
# 4                                  0
# 7                                  0
#
#    naics_description_TRUCK, UTILITY TRAILER, AND RV (RECREATIONAL VEHICLE) RENTAL AND LEASING  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    naics_description_USED HOUSEHOLD AND OFFICE GOODS MOVING  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    naics_description_VOCATIONAL REHABILITATION SERVICES  \
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
#    naics_description_WOOD OFFICE FURNITURE MANUFACTURING
# 0                                                  0
# 1                                                  0
# 3                                                  0
# 4                                                  0
# 7                                                  0
#
# [5 rows x 1552 columns]

# %%
df2.shape
# Out:
# (27246, 19)

# %%
cor = df3.corr()['set_aside'][:]
cor
# Out:
# set_aside                                                                                     1.000000
# contract_value                                                                               -0.038298
# awarding_sub_agency_name_DEFENSE ADVANCED RESEARCH PROJECTS AGENCY  (DARPA)                  -0.018220
# awarding_sub_agency_name_DEFENSE COMMISSARY AGENCY  (DECA)                                    0.112421
# awarding_sub_agency_name_DEFENSE CONTRACT MANAGEMENT AGENCY (DCMA)                           -0.055312
#                                                                                                 ...
# naics_description_TRAVEL AGENCIES                                                            -0.008659
# naics_description_TRUCK, UTILITY TRAILER, AND RV (RECREATIONAL VEHICLE) RENTAL AND LEASING   -0.017672
# naics_description_USED HOUSEHOLD AND OFFICE GOODS MOVING                                      0.017484
# naics_description_VOCATIONAL REHABILITATION SERVICES                                         -0.005587
# naics_description_WOOD OFFICE FURNITURE MANUFACTURING                                        -0.005587
# Name: set_aside, Length: 1552, dtype: float64

# %%
# Correlation with output variable
cor_target = abs(cor)
# Selecting highly correlated features
relevant_features = cor_target[cor_target>0.3]
print(relevant_features)
# Out:
# set_aside                                                                                       1.000000
# awarding_sub_agency_name_DEFENSE LOGISTICS AGENCY                                               0.471537
# awarding_office_name_DITCO-SCOTT                                                                0.314798
# awarding_office_name_DLA DISPOSTION SERVICE - EBS                                               0.438843
# funding_sub_agency_name_DEFENSE LOGISTICS AGENCY                                                0.474890
# funding_office_name_DLA DISPOSTION SERVICE - EBS                                                0.438843
# portfolio_group_Facility Related Services                                                       0.496446
# product_or_service_code_description_HOUSEKEEPING- WASTE TREATMENT/STORAGE                       0.479326
# product_or_service_code_description_IT AND TELECOM- TELECOMMUNICATIONS AND TRANSMISSION         0.303800
# naics_bucket_title_Administrative and Support and Waste Management and Remediation ServicesT    0.461173
# naics_bucket_title_InformationT                                                                 0.316876
# naics_description_HAZARDOUS WASTE TREATMENT AND DISPOSAL                                        0.482426
# naics_description_SATELLITE TELECOMMUNICATIONS                                                  0.311552
# Name: set_aside, dtype: float64
