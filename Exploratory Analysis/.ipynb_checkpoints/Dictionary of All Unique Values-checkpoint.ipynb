# %%
import pandas as pd
path = r'/home/team/Documents/Data-Oriented-Proposal-Engine/SpendingData/BeforeDummies.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0                   awarding_sub_agency_name  \
# 0           0                                 USTRANSCOM
# 1           1     WASHINGTON HEADQUARTERS SERVICES (WHS)
# 2           3                   DEFENSE LOGISTICS AGENCY
# 3           4  DEFENSE INFORMATION SYSTEMS AGENCY (DISA)
# 4           7                                 USTRANSCOM
#
#                awarding_office_name                 funding_sub_agency_name  \
# 0                     USTRANSCOM-AQ                   DEPT OF THE AIR FORCE
# 1  WASHINGTON HEADQUARTERS SERVICES  WASHINGTON HEADQUARTERS SERVICES (WHS)
# 2      DLA DISPOSTION SERVICE - EBS                DEFENSE LOGISTICS AGENCY
# 3                       DITCO-SCOTT                        DEPT OF THE ARMY
# 4                     USTRANSCOM-AQ                   DEPT OF THE AIR FORCE
#
#                 funding_office_name primary_place_of_performance_state_code  \
# 0                         HQ AMC TE                                      TX
# 1  PENTAGON FORCE PROTECTION AGENCY                                      VA
# 2      DLA DISPOSTION SERVICE - EBS                                      WI
# 3                   W4NH NETCOM HHC                                      TX
# 4                         HQ AMC TE                                      KS
#
#   award_or_idv_flag award_type type_of_contract_pricing  \
# 0             AWARD         DO         FIRM FIXED PRICE
# 1             AWARD         DO         FIRM FIXED PRICE
# 2             AWARD         DO         FIRM FIXED PRICE
# 3             AWARD   BPA CALL         FIRM FIXED PRICE
# 4             AWARD         DO         FIRM FIXED PRICE
#
#   dod_claimant_program_description type_of_set_aside_code  \
# 0                         SERVICES                   NONE
# 1                         SERVICES                   NONE
# 2                         SERVICES                     8A
# 3                         SERVICES                   NONE
# 4                         SERVICES                   NONE
#
#            contract_bundling national_interest_action  \
# 0  NOT A BUNDLED REQUIREMENT                     NONE
# 1  NOT A BUNDLED REQUIREMENT                     NONE
# 2  NOT A BUNDLED REQUIREMENT                     NONE
# 3  NOT A BUNDLED REQUIREMENT                     NONE
# 4  NOT A BUNDLED REQUIREMENT                     NONE
#
#                             gfe_gfp contract_financing  \
# 0  TRANSACTION DOES NOT USE GFE/GFP     NOT APPLICABLE
# 1  TRANSACTION DOES NOT USE GFE/GFP     NOT APPLICABLE
# 2  TRANSACTION DOES NOT USE GFE/GFP     NOT APPLICABLE
# 3  TRANSACTION DOES NOT USE GFE/GFP     NOT APPLICABLE
# 4  TRANSACTION DOES NOT USE GFE/GFP     NOT APPLICABLE
#
#                        portfolio_group  \
# 0              Transportation Services
# 1  Electronic & Communication Services
# 2            Facility Related Services
# 3  Electronic & Communication Services
# 4              Transportation Services
#
#                  product_or_service_code_description  \
# 0  TRANSPORTATION/TRAVEL/RELOCATION- TRAVEL/LODGI...
# 1  INSTALLATION OF EQUIPMENT- ALARM, SIGNAL, AND ...
# 2              HOUSEKEEPING- WASTE TREATMENT/STORAGE
# 3  IT AND TELECOM- TELECOMMUNICATIONS AND TRANSMI...
# 4  TRANSPORTATION/TRAVEL/RELOCATION- TRAVEL/LODGI...
#
#                                   naics_bucket_title  \
# 0                               Air TransportationT
# 1  Administrative and Support and Waste Managemen...
# 2  Administrative and Support and Waste Managemen...
# 3                                       InformationT
# 4                               Air TransportationT
#
#                                    naics_description  contract_value
# 0  NONSCHEDULED CHARTERED PASSENGER AIR TRANSPORT...        64925.82
# 1      SECURITY SYSTEMS SERVICES (EXCEPT LOCKSMITHS)         4897.96
# 2             HAZARDOUS WASTE TREATMENT AND DISPOSAL         5618.14
# 3                       SATELLITE TELECOMMUNICATIONS          163.92
# 4  NONSCHEDULED CHARTERED PASSENGER AIR TRANSPORT...       220000.00

# %%
df["portfolio_group"].unique()
