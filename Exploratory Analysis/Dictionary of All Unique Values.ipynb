# %%
import pandas as pd
path = r'/home/team/Documents/Data-Oriented-Proposal-Engine/SpendingData/BeforeDummies.csv'
df = pd.read_csv(path)

# %%
import numbers
import decimal

values = {}

for column in df:
    val = df[column].iloc[10]
    
    # Do not include columns with numbers
    if not isinstance(val, numbers.Number):
        uniqueList = df[column].unique()
        uniqueList.sort()
        values[column] = uniqueList

#       for unique in uniqueList:
#       print(column + ": " + unique)

# %%
import pprint
pprint.pprint(values)
# Out:
# {'award_or_idv_flag': array(['AWARD'], dtype=object),
#  'award_type': array(['BPA', 'BPA CALL', 'DCA', 'DEFINITIVE CONTRACT', 'DELIVERY ORDER',
#        'DO', 'PO', 'PURCHASE ORDER'], dtype=object),
#  'awarding_office_name': array(['CONTRACTING OPERATIONS DIVISION', 'DCMA AIMO - ST AUGUSTINE',
#        'DCMA AIMO ST AUGUSTINE', 'DCMA APO KELLY SAN ANTONIO',
#        'DCMA BOEING', 'DCSO COLUMBUS', 'DCSO FORT BELVOIR',
#        'DCSO NEW CUMBERLAND', 'DCSO PHILADELPHIA', 'DCSO RICHMOND',
#        'DCSO-NEW CUMBERLAND', 'DCSO-P NEW CUMBERLAND',
#        'DCSO-P/HARRISBURG', 'DDESS AREA SERVICE CENTER',
#        'DEF ADVANCED RESEARCH PROJECTS AGCY',
#        'DEFENSE CI AND SECURITY AGENCY', 'DEFENSE COMMISSARY AGENCY',
#        'DEFENSE CONTRACT MANAGEMENT AGENCY',
#        'DEFENSE CONTRACT MANAGMENT OFFICE',
#        'DEFENSE FINANCE AND ACCOUNTING SVC', 'DEFENSE HEALTH AGENCY',
#        'DEFENSE HEALTH AGENCY - AURORA',
#        'DEFENSE HEALTH AGENCY - FALLS CHURCH',
# ...
